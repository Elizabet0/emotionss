# %%
import numpy as np
import os
from PIL import Image
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
def load_images(data_dir):
    X, y = [], []
    classes = os.listdir(data_dir)
    for i, em in enumerate(classes):
        em_dir = os.path.join(data_dir, em)
        for img_name in os.listdir(em_dir): 
            img_path = os.path.join(em_dir, img_name)
            img = Image.open(img_path)
            img_array = np.array(img).flatten() / 255.0
            X.append(img_array)
            y.append(i)
    
    return np.array(X), np.array(y), classes

# %%
X_train, y_train, classes = load_images("../data/train")
X_test, y_test, _ = load_images("../data/test")

# %%
# !pip install catboost -q

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
X_trainn, X_val, y_trainn, y_val = train_test_split(X_train, y_train,test_size=0.15,random_state=42,stratify=y_train )

# %%
from catboost import CatBoostClassifier

model = CatBoostClassifier(
    iterations=300,
    learning_rate=0.1,
    depth=5,
    random_seed=42,
    verbose=10,
    eval_metric='Accuracy',
    early_stopping_rounds=50,
    use_best_model=True
)

model.fit(X_trainn, y_trainn,
    eval_set=(X_val, y_val),
    verbose=10)

train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

train_acc = accuracy_score(y_train, train_pred)
test_acc = accuracy_score(y_test, test_pred)

print(f"train acc: {train_acc:.3f}")
print(f"test acc: {test_acc:.3f}")
# Out:
# 0:	learn: 0.2862060	test: 0.2718830	best: 0.2718830 (0)	total: 1.47s	remaining: 7m 19s
# 10:	learn: 0.3152610	test: 0.3016020	best: 0.3016020 (10)	total: 13.1s	remaining: 5m 44s
# 20:	learn: 0.3325137	test: 0.3166938	best: 0.3166938 (20)	total: 24.7s	remaining: 5m 28s
# 30:	learn: 0.3525121	test: 0.3292315	best: 0.3292315 (29)	total: 37.6s	remaining: 5m 26s
# 40:	learn: 0.3667732	test: 0.3466450	best: 0.3466450 (40)	total: 52.4s	remaining: 5m 30s
# 50:	learn: 0.3781657	test: 0.3563966	best: 0.3563966 (50)	total: 1m 6s	remaining: 5m 25s
# 60:	learn: 0.3869355	test: 0.3628976	best: 0.3633620 (57)	total: 1m 22s	remaining: 5m 22s
# 70:	learn: 0.3947217	test: 0.3652194	best: 0.3652194 (70)	total: 1m 35s	remaining: 5m 8s
# 80:	learn: 0.4025900	test: 0.3680056	best: 0.3684699 (78)	total: 1m 49s	remaining: 4m 56s
# 90:	learn: 0.4101713	test: 0.3693987	best: 0.3724170 (88)	total: 2m 4s	remaining: 4m 46s
# 100:	learn: 0.4168101	test: 0.3717205	best: 0.3724170 (88)	total: 2m 16s	remaining: 4m 28s
# 110:	learn: 0.4243095	test: 0.3761319	best: 0.3761319 (110)	total: 2m 29s	remaining: 4m 14s
# 120:	learn: 0.4329563	test: 0.3805433	best: 0.3805433 (117)	total: 2m 41s	remaining: 3m 59s
# 130:	learn: 0.4380379	test: 0.3833295	best: 0.3847225 (126)	total: 2m 54s	remaining: 3m 45s
# 140:	learn: 0.4455782	test: 0.3868122	best: 0.3875087 (137)	total: 3m 6s	remaining: 3m 30s
# 150:	learn: 0.4525859	test: 0.3933132	best: 0.3933132 (150)	total: 3m 19s	remaining: 3m 16s
# 160:	learn: 0.4591017	test: 0.3988855	best: 0.3991177 (158)	total: 3m 31s	remaining: 3m 2s
# 170:	learn: 0.4665191	test: 0.4042257	best: 0.4042257 (170)	total: 3m 44s	remaining: 2m 49s
# 180:	learn: 0.4696336	test: 0.4035291	best: 0.4051544 (177)	total: 3m 57s	remaining: 2m 36s
# 190:	learn: 0.4767232	test: 0.4053866	best: 0.4058509 (186)	total: 4m 10s	remaining: 2m 22s
# 200:	learn: 0.4824195	test: 0.4070118	best: 0.4070118 (200)	total: 4m 23s	remaining: 2m 9s
# 210:	learn: 0.4863946	test: 0.4077084	best: 0.4077084 (210)	total: 4m 37s	remaining: 1m 56s
# 220:	learn: 0.4908204	test: 0.4102624	best: 0.4102624 (220)	total: 4m 50s	remaining: 1m 43s
# 230:	learn: 0.4950824	test: 0.4118876	best: 0.4130485 (229)	total: 5m 3s	remaining: 1m 30s
# 240:	learn: 0.5007786	test: 0.4146738	best: 0.4146738 (240)	total: 5m 15s	remaining: 1m 17s
# 250:	learn: 0.5062700	test: 0.4142094	best: 0.4151381 (242)	total: 5m 29s	remaining: 1m 4s
# 260:	learn: 0.5102041	test: 0.4128163	best: 0.4151381 (242)	total: 5m 42s	remaining: 51.2s
# 270:	learn: 0.5145480	test: 0.4167634	best: 0.4167634 (270)	total: 5m 54s	remaining: 37.9s
# 280:	learn: 0.5190558	test: 0.4158347	best: 0.4167634 (270)	total: 6m 7s	remaining: 24.9s
# 290:	learn: 0.5236046	test: 0.4179243	best: 0.4190852 (288)	total: 6m 20s	remaining: 11.8s
# 299:	learn: 0.5277436	test: 0.4197818	best: 0.4202461 (298)	total: 6m 31s	remaining: 0us
#
# bestTest = 0.420246111
# bestIteration = 298
#
# Shrink model to first 299 iterations.
# train acc: 0.511
# test acc: 0.424

# %%
model.save_model('../best_models/catboost_model.cbm')

# %%
print(f"My catboost acccuracy is {test_acc:.3f}!")
# Out:
# My catboost acccuracy is 0.424!
